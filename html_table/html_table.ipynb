# %%
import urllib
from bs4 import BeautifulSoup
# url = "http://www2.bmf.com.br/pages/portal/bmfbovespa/lumis/lum-taxas-referenciais-bmf-enUS.asp?Data=11/22/2017&Data1=20171122&slcTaxa=APR#"
# soup = BeautifulSoup(urllib.request.urlopen(url).read(),'lxml')
soup = BeautifulSoup(open('./2015_2018_rmb_to_ntd.html'))
rows=list()
# Out:
# /usr/lib/python3/dist-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
# print (soup.prettify())
for tr in soup.findAll('table'):
    for td in tr:
        rows.append(td.string)
temp_list=rows[3:]
final_list=[element for element in temp_list if element != '\n']

# %%
print (soup.table)
# Out:
# <table class="table">
# <thead>
# <tr>
# <th>日期</th>
# <th>汇率</th>
# <th>汇率(间接)</th>
# <th>备注</th>
# </tr>
# </thead>
# <tbody><tr>
# <td align="center">2018年04月18日</td>
# <td align="left" style="padding-left:20px;">    0.2159</td>
# <td align="left" style="padding-left:20px;">  4.632370</td>
# <td style="padding-left:10px;">1000TWD = 215.8722CNY</td>
# </tr>
# <tr>
# <td align="center">2018年04月17日</td>
# <td align="left" style="padding-left:20px;">    0.2149</td>
# <td align="left" style="padding-left:20px;">  4.653417</td>
# <td style="padding-left:10px;">1000TWD = 214.8958CNY</td>
# </tr>
# <tr>
# <td align="center">2018年04月16日</td>
# <td align="left" style="padding-left:20px;">    0.2153</td>
# <td align="left" style="padding-left:20px;">  4.644324</td>
# <td style="padding-left:10px;">1000TWD = 215.3166CNY</td>
# </tr>
# <tr>
# <td align="center">2018年04月15日</td>
# <td align="left" style="padding-left:20px;">    0.2160</td>
# ...

# %%
thead = soup.table.thead
print (thead.name)
print()
# Out:
# thead

# %%
tbody = soup.table.tbody
print (type(tbody), len(tbody))
# Out:
# <class 'bs4.element.Tag'> 2192

# %%
for tr in  tbody.children:
    print (tr)
# Out:
# <tr>
# <td align="center">2018年04月18日</td>
# <td align="left" style="padding-left:20px;">    0.2159</td>
# <td align="left" style="padding-left:20px;">  4.632370</td>
# <td style="padding-left:10px;">1000TWD = 215.8722CNY</td>
# </tr>
#
#
# <tr>
# <td align="center">2018年04月17日</td>
# <td align="left" style="padding-left:20px;">    0.2149</td>
# <td align="left" style="padding-left:20px;">  4.653417</td>
# <td style="padding-left:10px;">1000TWD = 214.8958CNY</td>
# </tr>
#
#
# <tr>
# <td align="center">2018年04月16日</td>
# <td align="left" style="padding-left:20px;">    0.2153</td>
# <td align="left" style="padding-left:20px;">  4.644324</td>
# <td style="padding-left:10px;">1000TWD = 215.3166CNY</td>
# </tr>
#
#
# <tr>
# <td align="center">2018年04月15日</td>
# <td align="left" style="padding-left:20px;">    0.2160</td>
# <td align="left" style="padding-left:20px;">  4.630587</td>
# <td style="padding-left:10px;">1000TWD = 215.9553CNY</td>
# </tr>
#
#
# <tr>
# ...

# %%
import bs4
for tr in  tbody.children:
#     print(type(tr))
    if type(tr)==bs4.element.Tag:
        for td in  tr.children:
            print(type(td))
#             print (td)
    if type(tr)== bs4.element.NavigableString:
        print(type(tr.string))
#         print(tr.string)
#         for td in  tr.stripped_strings:
#             print (td)
# Out:
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# ...

# %%
ss = soup.find_all('td')
s = ss[1]

# tr1 = list(ss[10])
# print(tr1)
# print()

x_list = []
y_list = []
index = 1
for s in ss[:10] :
    if index % 3 == 0 :
        tr = list(s)
#         print(tr[0])
        x_list.append(float(tr[0]))
        
    if index == 1:
        tr = list(s)
#         print(tr[0])
        y_list.append(tr[0])
    if index % 4 == 0:
        index = 0
    index += 1
print(x_list)
print(y_list)
# Out:
# [4.63237, 4.653417]
# ['2018年04月18日', '2018年04月17日', '2018年04月16日']

# %%
import numpy as np  
import matplotlib.pyplot as plt  
from datetime import datetime
import matplotlib.dates as mdates

y=[0,2,3]  
# y=[0,1]  

dates = ['01/02/1991', '01/03/1991', '01/04/1991']
x = [datetime.strptime(d, '%m/%d/%Y').date() for d in dates]
# 配置横坐标
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())

plt.plot(x, y)
plt.gcf().autofmt_xdate()  # 自动旋转日期标记
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
